# %% [markdown]
# # Exercices pratiques — Python pour le marketing digital
#
#
#
# | Référence | Contenu principal |
# |-----------|-------------------|
# | **Cours 1** | Notebook, variables, types (`int`, `float`, `str`, `bool`), `print`, f-strings, KPI (CPC, taux), listes et `len` |
# | **Cours 2** | `range`, boucles `for`, listes + boucles, deux listes parallèles, `if` / `else` |
# | **Cours 3** | Chaînes : concaténation, `len`, `upper`, `lower` ; listes : index, modification |
# | **Cours 4** | `for` sur listes, `for i in range(len(...))`, `if` / `elif` / `else`, boucle + condition |
#
# **Méthode :** complète chaque cellule **TODO**, exécute, puis ouvre la section **Corrections** en bas.
#
#
# ---

# %% [markdown]
# ## Partie A — Cours 1 : variables, types et KPI
#
# ### Exercice A1 (guidé) — Une campagne, deux indicateurs
#
# 1. Crée : `nom_campagne` (texte), `budget`, `clics`, `conversions`.
# 2. Calcule `cpc = budget / clics` et `taux_conversion = conversions / clics`.
# 3. Affiche **une phrase** avec une f-string : `Campagne ... : CPC = ... , taux = ...`

# %%
# TODO — Exercice A1
pass

# %% [markdown]
# ### Exercice A2 (autonomie) — Comparer deux campagnes
#
# Même logique pour **deux** campagnes. Affiche deux lignes récapitulatives puis une phrase indiquant **quelle** campagne a le **meilleur** taux (utilise `if` / `elif` / `else` si besoin pour l'égalité).

# %%
# TODO — Exercice A2
pass

# %% [markdown]
# ### Exercice A3 — Suivre les assignations (comme au Cours 1)
#
# Sans exécuter au début, devine la valeur finale de `x` :
#
# 1. `x = 4`
# 2. `x = x * 5`
# 3. `x = x - 7`
#
# Écris ta réponse en **commentaire**, puis décommente le code pour vérifier.

# %%
# TODO — Exercice A3
# Valeur attendue avant exécution : x = ...

# x = 4
# x = x * 5
# x = x - 7
# print(x)

pass

# %% [markdown]
# ### Exercice A4 — Types marketing
#
# Crée quatre variables : un entier (impressions), un float (ex. CTR 0.07), une chaîne (marque), un booléen (campagne active). Affiche chaque valeur **et** `type(...)`.

# %%
# TODO — Exercice A4
pass

# %% [markdown]
# ### Exercice A5 — Listes alignées (sans boucle, fin du Cours 1)
#
# Crée deux listes de même longueur :
#
# - `supports = ["Meta", "Google", "TikTok"]`
# - `depenses = [200, 350, 120]` (euros)
#
# 1. Affiche le nombre de supports avec `len(supports)`.
# 2. Affiche le **premier** support et la **dernière** dépense (indices `0` et `len(depenses) - 1`).
# 3. Modifie la dépense à l’index `1` (Google) pour la passer à **400**.
# 4. Affiche la liste `depenses` après modification.

# %%
# TODO — Exercice A5
pass

# %% [markdown]
# ### Exercice B1 — Indices et modification
#
# Données :

# %%
campagnes = ["SEA", "Social", "Email", "Affichage"]
budgets = [900, 400, 250, 600]

# %% [markdown]
# 1. Affiche le **premier** nom de campagne et le **dernier** budget (utilise `len` pour le dernier index).
# 2. Passe le budget de `"Email"` à **300**.
# 3. Affiche `budgets` mis à jour.

# %%
# TODO — Exercice B2 (exécute la cellule données juste au-dessus si besoin)
pass

# %% [markdown]
# ## Partie C — Cours 2 et 4 : `range` et boucles `for`
#
# ### Exercice C1 — Trois `range`
#
# Trois `print(list(range(...)))` pour obtenir :
#
# 1. Les entiers de **5 à 9** inclus.
# 2. Les multiples de **50** de 0 à 200 inclus : `0, 50, 100, 150, 200`.
# 3. Les entiers **pairs** de 2 à 10 inclus : `2, 4, 6, 8, 10`.

# %%
# TODO — Exercice C1
pass

# %% [markdown]
# ### Exercice C2 — Boucles `for` et `range`
#
# 1. `Touchpoint 1` … `Touchpoint 4`.
# 2. `Push jour 1` … `Push jour 5`.

# %%
# TODO — Exercice C2
pass

# %% [markdown]
# ### Exercice C3 — Parcourir une liste
#
# Liste `canaux` (au moins 4 éléments). Boucle `for canal in canaux:` → affiche `Canal actif : ...` pour chaque canal.

# %%
# TODO — Exercice C3
pass

# %% [markdown]
# ### Exercice C4 — Boucle + accumulateur (logique du Cours 2)
#
# On a les dépenses journalières d’une campagne (liste d’entiers) :
#
# `depenses_jour = [80, 45, 120, 30, 95]`
#
# 1. Parcours la liste avec `for montant in depenses_jour:`.
# 2. À chaque fois que `montant` est **strictement supérieur** à `50`, augmente une variable `nb_jours_forts` de **1** (initialise `nb_jours_forts = 0` avant la boucle).
# 3. Après la boucle, affiche : `Jours au-dessus de 50 euros : ...` avec la valeur finale de `nb_jours_forts`.

# %%
# TODO — Exercice C4
depenses_jour = [80, 45, 120, 30, 95]
pass

# %% [markdown]
# ## Partie D — Cours 4 : listes parallèles et conditions
#
# ### Exercice D1 — Mini reporting avec indice
#
# Deux listes de même longueur `noms` et `scores`. Boucle `for i in range(len(noms)):` → affiche `Lead ... — score ...`.

# %%
# TODO — Exercice D1
pass

# %% [markdown]
# ### Exercice D2 — `if` / `elif` / `else` (segment budget)
#
# `budget = 750` (change pour tester). Affiche :
#
# - `"Gros budget"` si `budget >= 1000`
# - `"Budget moyen"` si `500 <= budget < 1000`
# - `"Petit budget"` sinon

# %%
# TODO — Exercice D2
pass

# %% [markdown]
# ### Exercice D3 — Relances (style mini-examen)
#
# Données :

# %%
clients = ["Sara", "Tom", "Lina", "Yan", "Noa"]
montants = [95, 40, 150, 20, 200]
seuil_relance = 70

# %% [markdown]
# 1. `for i in range(len(clients)):`.
# 2. Affiche `A relancer` si `montants[i] < seuil_relance`, sinon `Client actif`.
# 3. Compte `nb_relance` (clients à relancer).
# 4. Après la boucle : `Nombre total de clients a relancer : ...`

# %%
# TODO — Exercice D3
pass

# %% [markdown]
# ### Exercice D4 (bonus) — Trois catégories
#
# Avec les mêmes `clients` et `montants` :
#
# - `Client premium` si montant `>= 180`
# - `Client actif` si `70 <= montant < 180`
# - `A relancer` si montant `< 70`
#
# Une ligne par client : prénom + catégorie.

# %%
# TODO — Exercice D4 (bonus)
pass

# %% [markdown]
# ---
#
# ## Entraînement type « mi-parcours » (≈ 45–60 min)
#
# **Barème indicatif (20 pts)** : E1 = 4, E2 = 4, E3 = 5, E4 = 7, bonus = +2.

# %% [markdown]
# ### Examen blanc — E1 (4 pts)
#
# Campagne `"Soldes_Hiver"`, budget `360`, clics `90`, conversions `9`. Variables, CPC, taux, phrase f-string.

# %%
# Examen blanc E1
pass

# %% [markdown]
# ### Examen blanc — E2 (4 pts)
#
# Données :

# %%
campagnes_ex = ["TikTok", "Meta", "YouTube", "LinkedIn"]
budgets_ex = [420, 310, 880, 150]

# %% [markdown]
# 1. Premier élément de `campagnes_ex`.
# 2. Dernier budget de `budgets_ex`.
# 3. Budget de `"YouTube"` → **950**.
# 4. Longueur de chaque liste.

# %%
# Examen blanc E2
pass

# %% [markdown]
# ### Examen blanc — E3 (5 pts)
#
# 1. `range` : afficher `Semaine 1` … `Semaine 4`.
# 2. Parcourir `medias` (cellule code ci-dessous), une ligne par média.
# 3. Boucle : `Notification #1` … `Notification #5`.

# %%
medias = ["Audio", "Video", "Display", "Native"]

# Examen blanc E3
pass

# %% [markdown]
# ### Examen blanc — E4 (7 pts)
#
# Données :

# %%
clients_ex = ["Eva", "Leo", "Mia", "Sam", "Zoe"]
montants_ex = [55, 120, 75, 30, 210]
seuil = 80

# %% [markdown]
# 1. `for i in range(len(...))`.
# 2. Si montant **strictement** inférieur à `seuil` → `Relance conseillee`, sinon `Panier OK`.
# 3. Variable `nb_relance` qui compte les relances.
# 4. Affiche `Nombre total de relances conseillees : ...`

# %%
# Examen blanc E4
pass

# %% [markdown]
# ### Examen blanc — Bonus (+2 pts)
#
# Mêmes listes : `VIP` si `>= 150`, `Standard` si `80 <= montant < 150`, `A risque` si `< 80`. Une ligne : prénom + catégorie.

# %%
# Examen blanc — Bonus
pass

# %% [markdown]
# ---
#
# ## Corrections

# %% [markdown]
# ### Correction A1

# %%
# Correction A1
nom_campagne = "Retargeting panier"
budget = 480
clics = 160
conversions = 16
cpc = budget / clics
taux_conversion = conversions / clics
print(f"Campagne {nom_campagne} : CPC = {cpc} , taux = {taux_conversion}")
# Out:
# Campagne Retargeting panier : CPC = 3.0 , taux = 0.1

# %% [markdown]
# ### Correction A2

# %%
# Correction A2
budget_a, clics_a, conv_a = 300, 150, 12
budget_b, clics_b, conv_b = 450, 300, 15
ta, tb = conv_a / clics_a, conv_b / clics_b
print(f"Campagne A — taux {ta}")
print(f"Campagne B — taux {tb}")
if ta > tb:
    print("Meilleur taux : campagne A")
elif tb > ta:
    print("Meilleur taux : campagne B")
else:
    print("Egalite des taux")
# Out:
# Campagne A — taux 0.08
# Campagne B — taux 0.05
# Meilleur taux : campagne A

# %% [markdown]
# ### Correction A3

# %%
# Correction A3 — x vaut 13
x = 4
x = x * 5
x = x - 7
print(x)
# Out:
# 13

# %% [markdown]
# ### Correction A4

# %%
# Correction A4
impressions = 10000
ctr = 0.052
marque = "ShopNow"
active = True
print(impressions, type(impressions))
print(ctr, type(ctr))
print(marque, type(marque))
print(active, type(active))
# Out:
# 10000 <class 'int'>
# 0.052 <class 'float'>
# ShopNow <class 'str'>
# True <class 'bool'>

# %% [markdown]
# ### Correction A5

# %%
# Correction A5 — parallel lists without loops (Course 1)
supports = ["Meta", "Google", "TikTok"]
depenses = [200, 350, 120]

print("Nombre de supports:", len(supports))
print("Premier support:", supports[0])
print("Derniere depense:", depenses[len(depenses) - 1])

depenses[1] = 400
print("Depenses mises a jour:", depenses)
# Out:
# Nombre de supports: 3
# Premier support: Meta
# Derniere depense: 120
# Depenses mises a jour: [200, 400, 120]

# %% [markdown]
# ### Correction B1

# %%
# Correction B1
produit = "Casque audio"
pays_cible = "Canada"
phrase = "Promo sur " + produit + " au " + pays_cible
print(phrase)
print(len(produit))
print(produit.upper())
print(produit.lower())
# Out:
# Promo sur Casque audio au Canada
# 12
# CASQUE AUDIO
# casque audio

# %% [markdown]
# ### Correction B2

# %%
# Correction B2
campagnes = ["SEA", "Social", "Email", "Affichage"]
budgets = [900, 400, 250, 600]
print(campagnes[0], budgets[len(budgets) - 1])
budgets[2] = 300
print(budgets)
# Out:
# SEA 600
# [900, 400, 300, 600]

# %% [markdown]
# ### Correction B3

# %%
# Correction B3
campagnes = ["SEA", "Social", "Email", "Affichage"]
budgets = [900, 400, 250, 600]
i = 1
print("La campagne " + campagnes[i] + " a un budget de " + str(budgets[i]) + " euros.")
# Out:
# La campagne Social a un budget de 400 euros.

# %% [markdown]
# ### Correction C1

# %%
# Correction C1
print(list(range(5, 10)))
print(list(range(0, 201, 50)))
print(list(range(2, 11, 2)))
# Out:
# [5, 6, 7, 8, 9]
# [0, 50, 100, 150, 200]
# [2, 4, 6, 8, 10]

# %% [markdown]
# ### Correction C2

# %%
# Correction C2
for t in range(1, 5):
    print(f"Touchpoint {t}")
for j in range(1, 6):
    print(f"Push jour {j}")
# Out:
# Touchpoint 1
# Touchpoint 2
# Touchpoint 3
# Touchpoint 4
# Push jour 1
# Push jour 2
# Push jour 3
# Push jour 4
# Push jour 5

# %% [markdown]
# ### Correction C3

# %%
# Correction C3
canaux = ["Email", "SMS", "Push", "WhatsApp"]
for canal in canaux:
    print(f"Canal actif : {canal}")
# Out:
# Canal actif : Email
# Canal actif : SMS
# Canal actif : Push
# Canal actif : WhatsApp

# %% [markdown]
# ### Correction C4

# %%
# Correction C4 — loop with a counter (Course 2 style)
depenses_jour = [80, 45, 120, 30, 95]
nb_jours_forts = 0
for montant in depenses_jour:
    if montant > 50:
        nb_jours_forts = nb_jours_forts + 1
print(f"Jours au-dessus de 50 euros : {nb_jours_forts}")
# Out:
# Jours au-dessus de 50 euros : 3

# %% [markdown]
# ### Correction D1

# %%
# Correction D1
noms = ["Ana", "Ben", "Cleo"]
scores = [12, 44, 38]
for i in range(len(noms)):
    print(f"Lead {noms[i]} — score {scores[i]}")
# Out:
# Lead Ana — score 12
# Lead Ben — score 44
# Lead Cleo — score 38

# %% [markdown]
# ### Correction D2

# %%
# Correction D2
budget = 750
if budget >= 1000:
    print("Gros budget")
elif budget >= 500:
    print("Budget moyen")
else:
    print("Petit budget")
# Out:
# Budget moyen

# %% [markdown]
# ### Correction D3

# %%
# Correction D3
clients = ["Sara", "Tom", "Lina", "Yan", "Noa"]
montants = [95, 40, 150, 20, 200]
seuil_relance = 70
nb_relance = 0
for i in range(len(clients)):
    if montants[i] < seuil_relance:
        print(f"{clients[i]} : A relancer")
        nb_relance = nb_relance + 1
    else:
        print(f"{clients[i]} : Client actif")
print(f"Nombre total de clients a relancer : {nb_relance}")
# Out:
# Sara : Client actif
# Tom : A relancer
# Lina : Client actif
# Yan : A relancer
# Noa : Client actif
# Nombre total de clients a relancer : 2

# %% [markdown]
# ### Correction D4

# %%
# Correction D4 (bonus)
clients = ["Sara", "Tom", "Lina", "Yan", "Noa"]
montants = [95, 40, 150, 20, 200]
for i in range(len(clients)):
    m = montants[i]
    if m >= 180:
        cat = "Client premium"
    elif m >= 70:
        cat = "Client actif"
    else:
        cat = "A relancer"
    print(f"{clients[i]} — {cat}")
# Out:
# Sara — Client actif
# Tom — A relancer
# Lina — Client actif
# Yan — A relancer
# Noa — Client premium

# %% [markdown]
# ### Correction E1

# %%
# Correction E1
nom = "Soldes_Hiver"
budget = 360
clics = 90
conversions = 9
cpc = budget / clics
taux = conversions / clics
print(f"Campagne {nom} : CPC = {cpc} , taux = {taux}")
# Out:
# Campagne Soldes_Hiver : CPC = 4.0 , taux = 0.1

# %% [markdown]
# ### Correction E2

# %%
# Correction E2
campagnes_ex = ["TikTok", "Meta", "YouTube", "LinkedIn"]
budgets_ex = [420, 310, 880, 150]
print(campagnes_ex[0])
print(budgets_ex[len(budgets_ex) - 1])
budgets_ex[2] = 950
print(len(campagnes_ex), len(budgets_ex))
print(budgets_ex)
# Out:
# TikTok
# 150
# 4 4
# [420, 310, 950, 150]

# %% [markdown]
# ### Correction E3

# %%
# Correction E3
medias = ["Audio", "Video", "Display", "Native"]
for s in range(1, 5):
    print(f"Semaine {s}")
for m in medias:
    print(m)
for n in range(1, 6):
    print(f"Notification #{n}")
# Out:
# Semaine 1
# Semaine 2
# Semaine 3
# Semaine 4
# Audio
# Video
# Display
# Native
# Notification #1
# Notification #2
# Notification #3
# Notification #4
# Notification #5

# %% [markdown]
# ### Correction E4

# %%
# Correction E4
clients_ex = ["Eva", "Leo", "Mia", "Sam", "Zoe"]
montants_ex = [55, 120, 75, 30, 210]
seuil = 80
nb_relance = 0
for i in range(len(clients_ex)):
    if montants_ex[i] < seuil:
        print("Relance conseillee", clients_ex[i])
        nb_relance += 1
    else:
        print("Panier OK", clients_ex[i])
print(f"Nombre total de relances conseillees : {nb_relance}")
# Out:
# Relance conseillee Eva
# Panier OK Leo
# Relance conseillee Mia
# Relance conseillee Sam
# Panier OK Zoe
# Nombre total de relances conseillees : 3

# %% [markdown]
# ### Correction Bonus

# %%
# Correction bonus
clients_ex = ["Eva", "Leo", "Mia", "Sam", "Zoe"]
montants_ex = [55, 120, 75, 30, 210]
for i in range(len(clients_ex)):
    m = montants_ex[i]
    if m >= 150:
        c = "VIP"
    elif m >= 80:
        c = "Standard"
    else:
        c = "A risque"
    print(f"{clients_ex[i]} — {c}")
# Out:
# Eva — A risque
# Leo — Standard
# Mia — A risque
# Sam — A risque
# Zoe — VIP
